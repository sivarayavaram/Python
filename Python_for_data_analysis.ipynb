# %%
import pandas as pd

# %%
import numpy as np
import scipy as sp
import matplotlib as mpl
import seaborn as sns

# %%
df = pd.read_csv("http://rcs.bu.edu/examples/python/data_analysis/Salaries.csv")

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df[:10] # to get the first 10 rows
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300
# 8       Prof          A   29       19  Male   94350
# 9       Prof          A   51       51  Male   57800

# %%
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df.shape
# Out:
# (78, 6)

# %%
df.columns # Column names
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
len(df) # To know the number of rows
# Out:
# 78

# %%
df.columns.get_values() # Column names
# Out:
# array(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'],
#       dtype=object)

# %%
list(df) # Column names
# Out:
# ['rank', 'discipline', 'phd', 'service', 'sex', 'salary']

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df.std()
# Out:
# phd           12.498425
# service       12.139768
# salary     28293.661022
# dtype: float64

# %%
df[50:].mean() # Mean for first 50 records
# Out:
# phd           16.464286
# service       10.500000
# salary     97728.500000
# dtype: float64

# %%
df.mean() # for all records
# Out:
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %%
df.service.head()
# OR
df['phd'].head()
# Out:
# 0    56
# 1    12
# 2    23
# 3    40
# 4    20
# Name: phd, dtype: int64

# %%
df.salary.describe()
# Out:
# count        78.000000
# mean     108023.782051
# std       28293.661022
# min       57800.000000
# 25%       88612.500000
# 50%      104671.000000
# 75%      126774.750000
# max      186960.000000
# Name: salary, dtype: float64

# %%
df['salary'].describe()
# Out:
# count        78.000000
# mean     108023.782051
# std       28293.661022
# min       57800.000000
# 25%       88612.500000
# 50%      104671.000000
# 75%      126774.750000
# max      186960.000000
# Name: salary, dtype: float64

# %%
df.salary.count()
# Out:
# 78

# %%
df.salary.mean()
# Out:
# 108023.78205128205

# %%
df_rank = df.groupby('rank')

# %%
df_rank.mean()
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
df.groupby('rank')[['salary']].mean()
# Out:
#                   salary
# rank
# AssocProf   91786.230769
# AsstProf    81362.789474
# Prof       123624.804348

# %%
df.salary>120000 # output is boolean
# Out:
# 0      True
# 1     False
# 2     False
# 3      True
# 4     False
# 5      True
# 6     False
# 7      True
# 8     False
# 9     False
# 10     True
# 11     True
# 12    False
# 13     True
# 14     True
# 15     True
# 16    False
# 17    False
# 18    False
# 19     True
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26     True
# 27     True
# 28    False
# 29     True
#       ...
# 48    False
# 49     True
# 50    False
# 51     True
# 52    False
# 53    False
# 54    False
# 55    False
# 56    False
# 57    False
# 58     True
# 59    False
# 60    False
# 61    False
# 62    False
# 63    False
# 64    False
# 65    False
# 66    False
# 67    False
# 68    False
# 69    False
# 70    False
# 71    False
# 72     True
# 73    False
# 74    False
# 75     True
# 76    False
# 77    False
# Name: salary, Length: 78, dtype: bool

# %%
df[df.salary>120000] # filtering the "True" data into the data frame
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 3   Prof          A   40       31    Male  131205
# 5   Prof          A   20       20    Male  122400
# 7   Prof          A   18       18    Male  126300
# 10  Prof          B   39       33    Male  128250
# 11  Prof          B   23       23    Male  134778
# 13  Prof          B   35       33    Male  162200
# 14  Prof          B   25       19    Male  153750
# 15  Prof          B   17        3    Male  150480
# 19  Prof          A   29       27    Male  150500
# 26  Prof          A   38       19    Male  148750
# 27  Prof          A   45       43    Male  155865
# 29  Prof          B   21       20    Male  123683
# 31  Prof          B   22       21    Male  155750
# 35  Prof          B   28       23    Male  126933
# 36  Prof          B   45       45    Male  146856
# 39  Prof          B   18       18  Female  129000
# 40  Prof          A   39       36  Female  137000
# ...

# %%
df[df.phd>20]
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 19       Prof          A   29       27    Male  150500
# 21       Prof          A   33       30    Male  103106
# 24       Prof          A   30       23    Male   91100
# 25       Prof          B   35       31    Male   99418
# 26       Prof          A   38       19    Male  148750
# 27       Prof          A   45       43    Male  155865
# 29       Prof          B   21       20    Male  123683
# ...

# %%
df_f = df[df['sex'] == 'Female']

# %%
df_f.head()
# Out:
#          rank discipline  phd  service     sex  salary
# 39       Prof          B   18       18  Female  129000
# 40       Prof          A   39       36  Female  137000
# 41  AssocProf          A   13        8  Female   74830
# 42   AsstProf          B    4        2  Female   80225
# 43   AsstProf          B    5        0  Female   77000

# %%
df['salary'].head()
# Out:
# 0    186960
# 1     93000
# 2    110515
# 3    131205
# 4    104800
# Name: salary, dtype: int64

# %%
df[['rank','salary']].head()
# Out:
#    rank  salary
# 0  Prof  186960
# 1  Prof   93000
# 2  Prof  110515
# 3  Prof  131205
# 4  Prof  104800

# %%
df[10:20] # selecting rows
# Out:
#         rank discipline  phd  service   sex  salary
# 10      Prof          B   39       33  Male  128250
# 11      Prof          B   23       23  Male  134778
# 12  AsstProf          B    1        0  Male   88000
# 13      Prof          B   35       33  Male  162200
# 14      Prof          B   25       19  Male  153750
# 15      Prof          B   17        3  Male  150480
# 16  AsstProf          B    8        3  Male   75044
# 17  AsstProf          B    4        0  Male   92000
# 18      Prof          A   19        7  Male  107300
# 19      Prof          A   29       27  Male  150500

# %%
df.loc[10:20,['rank','sex']]
# Out:
#         rank   sex
# 10      Prof  Male
# 11      Prof  Male
# 12  AsstProf  Male
# 13      Prof  Male
# 14      Prof  Male
# 15      Prof  Male
# 16  AsstProf  Male
# 17  AsstProf  Male
# 18      Prof  Male
# 19      Prof  Male
# 20  AsstProf  Male

# %%
df.iloc[10:20,[0,3,5]]
# Out:
#         rank  service  salary
# 10      Prof       33  128250
# 11      Prof       23  134778
# 12  AsstProf        0   88000
# 13      Prof       33  162200
# 14      Prof       19  153750
# 15      Prof        3  150480
# 16  AsstProf        3   75044
# 17  AsstProf        0   92000
# 18      Prof        7  107300
# 19      Prof       27  150500

# %%
df.iloc[0] # first row of data frame
df.iloc[i] # (i) th row
df.iloc[-1] # last row

df.iloc[:,0] # First column
df.iloc[:, -1] # lst column

df.iloc[0:7] # first 7 rows
df.iloc[:,0:2] # first 2 columns
df.iloc[1:3, 0:2] # first and 2nd rows and first 2 columns
df.iloc[[0,5],[1,3]] # 1st and 5th row and 1st and 3rd columns
# Out:
#   discipline  service
# 0          B       49
# 5          A       20

# %%
df_sorted = df.sort_values(by=['service','salary'],ascending=[True, False])

# %%
df_sorted.head()
# Out:
#         rank discipline  phd  service     sex  salary
# 52      Prof          A   12        0  Female  105000
# 17  AsstProf          B    4        0    Male   92000
# 12  AsstProf          B    1        0    Male   88000
# 23  AsstProf          A    2        0    Male   85000
# 43  AsstProf          B    5        0  Female   77000

# %%
flights = pd.read_csv("http://rcs.bu.edu/examples/python/data_analysis/flights.csv")

# %%
flights.head()
# Out:
#    year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier tailnum  \
# 0  2013      1    1     517.0        2.0     830.0       11.0      UA  N14228
# 1  2013      1    1     533.0        4.0     850.0       20.0      UA  N24211
# 2  2013      1    1     542.0        2.0     923.0       33.0      AA  N619AA
# 3  2013      1    1     554.0       -6.0     812.0      -25.0      DL  N668DN
# 4  2013      1    1     554.0       -4.0     740.0       12.0      UA  N39463
#
#    flight origin dest  air_time  distance  hour  minute
# 0    1545    EWR  IAH     227.0      1400   5.0    17.0
# 1    1714    LGA  IAH     227.0      1416   5.0    33.0
# 2    1141    JFK  MIA     160.0      1089   5.0    42.0
# 3     461    LGA  ATL     116.0       762   5.0    54.0
# 4    1696    EWR  ORD     150.0       719   5.0    54.0

# %%
flights[flights.isnull().any(axis = 1)].head()  
# Missing values are marked as NaN, and select the rows that have at-least one missing value
# Out:
#      year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 330  2013      1    1    1807.0       29.0    2251.0        NaN      UA
# 403  2013      1    1       NaN        NaN       NaN        NaN      AA
# 404  2013      1    1       NaN        NaN       NaN        NaN      AA
# 855  2013      1    2    2145.0       16.0       NaN        NaN      UA
# 858  2013      1    2       NaN        NaN       NaN        NaN      AA
#
#     tailnum  flight origin dest  air_time  distance  hour  minute
# 330  N31412    1228    EWR  SAN       NaN      2425  18.0     7.0
# 403  N3EHAA     791    LGA  DFW       NaN      1389   NaN     NaN
# 404  N3EVAA    1925    LGA  MIA       NaN      1096   NaN     NaN
# 855  N12221    1299    EWR  RSW       NaN      1068  21.0    45.0
# 858     NaN     133    JFK  LAX       NaN      2475   NaN     NaN

# %%
flights[['dep_delay','arr_delay']].agg(['min','mean','max'])
# Out:
#         dep_delay    arr_delay
# min    -33.000000   -75.000000
# mean     9.463773     2.094537
# max   1014.000000  1007.000000

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
y = [3,10,7,5,3,4.5,6,8.1]
N = len(y)
x = range(N)
width = 1/1.5

plt.bar(x,y,width,color = 'blue')
# Out:
# <BarContainer object of 8 artists>
